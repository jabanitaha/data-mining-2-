# %% [markdown]
# <a href="https://colab.research.google.com/github/jabanitaha/data-mining-2-/blob/main/DL0101EN_3_1_Regression_with_Keras_Answered_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://cognitiveclass.ai"><img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0101EN-SkillsNetwork/images/IDSN-logo.png" width="400"> </a>
#
# # Regression Models with Keras
#
# Estimated time needed: **45** mins

# %% [markdown]
# ## Introduction

# %% [markdown]
# As we discussed in the videos, despite the popularity of more powerful libraries such as PyToch and TensorFlow, they are not easy to use and have a steep learning curve. So, for people who are just starting to learn deep learning, there is no better library to use other than the Keras library.
#
# Keras is a high-level API for building deep learning models. It has gained favor for its ease of use and syntactic simplicity facilitating fast development. As you will see in this lab and the other labs in this course, building a very complex deep learning network can be achieved with Keras with only few lines of code. You will appreciate Keras even more, once you learn how to build deep models using PyTorch and TensorFlow in the other courses.
#
# So, in this lab, you will learn how to use the Keras library to build a regression model.

# %% [markdown]
# ## Objectives for this Notebook
# * How to use the Keras library to build a regression model
# * Download and clean the data set
# * Build a neural network
# * Train and test the network

# %% [markdown]
# ## Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
# 1. <a href="#item31">Download and Clean the Data Set</a>
# 2. <a href="#item32">Import Keras Packages</a>
# 3. <a href="#item33">Build a Neural Network</a>
# 4. <a href="#item34">Train and Test the Network</a>
#
# </font>
# </div>

# %% [markdown]
# <a id="item31"></a>

# %% [markdown]
# ## Download and Clean the  Data Set

# %% [markdown]
# Let's start by importing the <em>pandas</em> and the Numpy libraries.

# %%
# All Libraries required for this lab are listed below. The libraries pre-installed on Skills Network Labs are commented.
# If you run this notebook on a different environment, e.g. your desktop, you may need to uncomment and install certain libraries.
# !pip install numpy==2.0.2
# !pip install pandas==2.2.2
# !pip install tensorflow_cpu==2.18.0
# Out:
# Requirement already satisfied: numpy==2.0.2 in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: pandas==2.2.2 in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas==2.2.2) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas==2.2.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas==2.2.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas==2.2.2) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas==2.2.2) (1.17.0)
# Collecting tensorflow_cpu==2.18.0
#   Downloading tensorflow_cpu-2.18.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow_cpu==2.18.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow_cpu==2.18.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow_cpu==2.18.0) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow_cpu==2.18.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow_cpu==2.18.0) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow_cpu==2.18.0) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow_cpu==2.18.0) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow_cpu==2.18.0) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow_cpu==2.18.0) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow_cpu==2.18.0) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow_cpu==2.18.0) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow_cpu==2.18.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow_cpu==2.18.0) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow_cpu==2.18.0) (4.14.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow_cpu==2.18.0) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow_cpu==2.18.0) (1.73.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow_cpu==2.18.0) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow_cpu==2.18.0) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow_cpu==2.18.0) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow_cpu==2.18.0) (3.14.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow_cpu==2.18.0) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow_cpu==2.18.0) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow_cpu==2.18.0) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow_cpu==2.18.0) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow_cpu==2.18.0) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow_cpu==2.18.0) (0.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow_cpu==2.18.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow_cpu==2.18.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow_cpu==2.18.0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow_cpu==2.18.0) (2025.6.15)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow_cpu==2.18.0) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow_cpu==2.18.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow_cpu==2.18.0) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow_cpu==2.18.0) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow_cpu==2.18.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow_cpu==2.18.0) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow_cpu==2.18.0) (0.1.2)
# Downloading tensorflow_cpu-2.18.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (230.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 230.2/230.2 MB 6.1 MB/s eta 0:00:00
# Installing collected packages: tensorflow_cpu
# Successfully installed tensorflow_cpu-2.18.0

# %% [markdown]
# ##### To use Keras, you will also need to install a backend framework – such as TensorFlow.
#
# If you install TensorFlow 2.16 or above, it will install Keras by default.
#
# We are using the CPU version of tensorflow since we are dealing with smaller datasets.
# You may install the GPU version of tensorflow on your machine to accelarate the processing of larger datasets

# %%
import pandas as pd
import numpy as np
import keras

import warnings
warnings.simplefilter('ignore', FutureWarning)

# %% [markdown]
# We will be playing around with the same dataset that we used in the videos.
#
# <strong>The dataset is about the compressive strength of different samples of concrete based on the volumes of the different ingredients that were used to make them. Ingredients include:</strong>
#
# * Cement
# * Blast furnace slag
# * Fly ash
# * Water
# * Superplasticizer
# * Coarse aggregate
# * Fine aggregate

# %% [markdown]
# Let's download the data and read it into a <em>pandas</em> dataframe.

# %%
filepath='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv'
concrete_data = pd.read_csv(filepath)

concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# So the first concrete sample has 540 cubic meter of cement, 0 cubic meter of blast furnace slag, 0 cubic meter of fly ash, 162 cubic meter of water, 2.5 cubic meter of superplaticizer, 1040 cubic meter of coarse aggregate, 676 cubic meter of fine aggregate. Such a concrete mix which is 28 days old, has a compressive strength of 79.99 MPa.

# %% [markdown]
# #### Let's check how many data points we have

# %%
concrete_data.shape
# Out:
# (1030, 9)

# %% [markdown]
# So, there are approximately 1000 samples to train our model on. Because of the few samples, we have to be careful not to overfit the training data.

# %% [markdown]
# Let's check the dataset for any missing values.

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# The data looks very clean and is ready to be used to build our model.

# %% [markdown]
# #### Split data into predictors and target

# %% [markdown]
# The target variable in this problem is the concrete sample strength. Therefore, our predictors will be all the other columns.

# %%
concrete_data_columns = concrete_data.columns

# %%
predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # all columns except Strength
target = concrete_data['Strength'] # Strength column

# %% [markdown]
# <a id="item2"></a>

# %% [markdown]
# Let's do a quick sanity check of the predictors and the target dataframes.

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %% [markdown]
# Finally, the last step is to normalize the data by substracting the mean and dividing by the standard deviation.

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %% [markdown]
# Let's save the number of predictors to *n_cols* since we will need this number when building our network.

# %%
n_cols = predictors_norm.shape[1] # number of predictors

# %% [markdown]
# <a id="item1"></a>

# %% [markdown]
# <a id='item32'></a>

# %% [markdown]
# ##  Import Keras Packages
#
# ##### Let's import the rest of the packages from the Keras library that we will need to build our regression model.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Input

# %% [markdown]
# <a id='item33'></a>

# %% [markdown]
# ## Build a Neural Network

# %% [markdown]
# Let's define a function that defines our regression model for us so that we can conveniently call it to create our model.

# %%
# define regression model
def regression_model():
    # create model
    model = Sequential()
    model.add(Input(shape=(n_cols,)))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))

    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# The above function create a model that has two hidden layers, each of 50 hidden units.

# %% [markdown]
# <a id="item4"></a>

# %% [markdown]
# ## Train and Test the Network

# %% [markdown]
# Let's call the function now to create our model.

# %%
# build the model
model = regression_model()

# %% [markdown]
# Next, we will train and test the model at the same time using the *fit* method. We will leave out 30% of the data for validation and we will train the model for 100 epochs.

# %%
# fit the model
model.fit(predictors_norm, target, validation_split=0.3, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 23/23 - 2s - 65ms/step - loss: 1634.2120 - val_loss: 1137.6263
# Epoch 2/100
# 23/23 - 0s - 16ms/step - loss: 1493.8188 - val_loss: 1018.4966
# Epoch 3/100
# 23/23 - 0s - 13ms/step - loss: 1265.3280 - val_loss: 830.2150
# Epoch 4/100
# 23/23 - 0s - 14ms/step - loss: 925.0533 - val_loss: 588.5110
# Epoch 5/100
# 23/23 - 0s - 14ms/step - loss: 567.7471 - val_loss: 365.8089
# Epoch 6/100
# 23/23 - 0s - 13ms/step - loss: 330.5714 - val_loss: 237.7331
# Epoch 7/100
# 23/23 - 0s - 5ms/step - loss: 249.8830 - val_loss: 193.7235
# Epoch 8/100
# 23/23 - 0s - 6ms/step - loss: 231.0897 - val_loss: 179.2513
# Epoch 9/100
# 23/23 - 0s - 6ms/step - loss: 217.2162 - val_loss: 174.9403
# Epoch 10/100
# 23/23 - 0s - 6ms/step - loss: 207.3702 - val_loss: 169.3379
# Epoch 11/100
# 23/23 - 0s - 6ms/step - loss: 199.3108 - val_loss: 165.4533
# Epoch 12/100
# 23/23 - 0s - 5ms/step - loss: 192.5161 - val_loss: 164.0145
# Epoch 13/100
# 23/23 - 0s - 6ms/step - loss: 187.0304 - val_loss: 159.7105
# Epoch 14/100
# 23/23 - 0s - 6ms/step - loss: 181.8004 - val_loss: 158.4777
# Epoch 15/100
# 23/23 - 0s - 6ms/step - loss: 177.3422 - val_loss: 153.8224
# Epoch 16/100
# 23/23 - 0s - 7ms/step - loss: 173.2467 - val_loss: 150.8543
# Epoch 17/100
# 23/23 - 0s - 12ms/step - loss: 170.0564 - val_loss: 150.5844
# Epoch 18/100
# 23/23 - 0s - 5ms/step - loss: 165.9079 - val_loss: 147.5223
# Epoch 19/100
# 23/23 - 0s - 6ms/step - loss: 163.5994 - val_loss: 144.8371
# Epoch 20/100
# 23/23 - 0s - 5ms/step - loss: 160.8108 - val_loss: 143.2618
# Epoch 21/100
# 23/23 - 0s - 5ms/step - loss: 158.6514 - val_loss: 143.1480
# Epoch 22/100
# 23/23 - 0s - 6ms/step - loss: 156.1942 - val_loss: 141.3213
# Epoch 23/100
# 23/23 - 0s - 7ms/step - loss: 154.5804 - val_loss: 137.4871
# Epoch 24/100
# 23/23 - 0s - 6ms/step - loss: 153.2899 - val_loss: 140.3217
# Epoch 25/100
# 23/23 - 0s - 6ms/step - loss: 150.3277 - val_loss: 136.1133
# Epoch 26/100
# 23/23 - 0s - 7ms/step - loss: 148.4034 - val_loss: 135.0909
# Epoch 27/100
# 23/23 - 0s - 13ms/step - loss: 147.3406 - val_loss: 133.7691
# Epoch 28/100
# 23/23 - 0s - 6ms/step - loss: 145.6669 - val_loss: 136.3167
# Epoch 29/100
# 23/23 - 0s - 5ms/step - loss: 143.6486 - val_loss: 133.7671
# Epoch 30/100
# 23/23 - 0s - 6ms/step - loss: 142.1595 - val_loss: 132.7885
# Epoch 31/100
# 23/23 - 0s - 6ms/step - loss: 140.8144 - val_loss: 134.3089
# Epoch 32/100
# 23/23 - 0s - 6ms/step - loss: 139.3186 - val_loss: 131.5012
# Epoch 33/100
# 23/23 - 0s - 6ms/step - loss: 138.1160 - val_loss: 130.6296
# Epoch 34/100
# 23/23 - 0s - 7ms/step - loss: 136.4964 - val_loss: 131.6862
# Epoch 35/100
# 23/23 - 0s - 5ms/step - loss: 135.8425 - val_loss: 130.7264
# Epoch 36/100
# 23/23 - 0s - 6ms/step - loss: 134.8221 - val_loss: 131.0524
# Epoch 37/100
# 23/23 - 0s - 6ms/step - loss: 133.1585 - val_loss: 128.6967
# Epoch 38/100
# 23/23 - 0s - 6ms/step - loss: 132.0349 - val_loss: 129.0510
# Epoch 39/100
# 23/23 - 0s - 14ms/step - loss: 130.5262 - val_loss: 129.1026
# Epoch 40/100
# 23/23 - 0s - 11ms/step - loss: 129.4808 - val_loss: 129.0715
# Epoch 41/100
# 23/23 - 0s - 6ms/step - loss: 127.9184 - val_loss: 129.0735
# Epoch 42/100
# 23/23 - 0s - 6ms/step - loss: 127.0418 - val_loss: 131.3414
# Epoch 43/100
# 23/23 - 0s - 6ms/step - loss: 125.2488 - val_loss: 127.7319
# Epoch 44/100
# 23/23 - 0s - 6ms/step - loss: 123.6042 - val_loss: 129.0043
# Epoch 45/100
# 23/23 - 0s - 5ms/step - loss: 122.2056 - val_loss: 127.6858
# Epoch 46/100
# 23/23 - 0s - 6ms/step - loss: 121.0288 - val_loss: 128.3022
# Epoch 47/100
# 23/23 - 0s - 7ms/step - loss: 119.5825 - val_loss: 127.4476
# Epoch 48/100
# 23/23 - 0s - 12ms/step - loss: 117.8754 - val_loss: 129.1321
# Epoch 49/100
# 23/23 - 0s - 6ms/step - loss: 115.9367 - val_loss: 127.3404
# Epoch 50/100
# 23/23 - 0s - 6ms/step - loss: 114.4571 - val_loss: 129.0801
# Epoch 51/100
# 23/23 - 0s - 7ms/step - loss: 111.9992 - val_loss: 126.4879
# Epoch 52/100
# 23/23 - 0s - 12ms/step - loss: 110.4879 - val_loss: 124.8198
# Epoch 53/100
# 23/23 - 0s - 6ms/step - loss: 107.8327 - val_loss: 126.6416
# Epoch 54/100
# 23/23 - 0s - 6ms/step - loss: 105.5252 - val_loss: 125.2215
# Epoch 55/100
# 23/23 - 0s - 5ms/step - loss: 104.3255 - val_loss: 121.9983
# Epoch 56/100
# 23/23 - 0s - 7ms/step - loss: 100.5366 - val_loss: 124.1860
# Epoch 57/100
# 23/23 - 0s - 13ms/step - loss: 98.0013 - val_loss: 124.8850
# Epoch 58/100
# 23/23 - 0s - 7ms/step - loss: 95.6045 - val_loss: 123.1111
# Epoch 59/100
# 23/23 - 0s - 6ms/step - loss: 91.9173 - val_loss: 121.4484
# Epoch 60/100
# 23/23 - 0s - 5ms/step - loss: 90.1748 - val_loss: 118.2380
# Epoch 61/100
# 23/23 - 0s - 8ms/step - loss: 86.8808 - val_loss: 120.6183
# Epoch 62/100
# 23/23 - 0s - 13ms/step - loss: 84.4170 - val_loss: 121.1894
# Epoch 63/100
# 23/23 - 0s - 12ms/step - loss: 81.9298 - val_loss: 116.0542
# Epoch 64/100
# 23/23 - 0s - 6ms/step - loss: 78.4352 - val_loss: 118.8675
# Epoch 65/100
# 23/23 - 0s - 5ms/step - loss: 76.3203 - val_loss: 112.5184
# Epoch 66/100
# 23/23 - 0s - 6ms/step - loss: 73.5616 - val_loss: 116.8873
# Epoch 67/100
# 23/23 - 0s - 7ms/step - loss: 72.1519 - val_loss: 110.2813
# Epoch 68/100
# 23/23 - 0s - 15ms/step - loss: 69.3398 - val_loss: 113.3366
# Epoch 69/100
# 23/23 - 0s - 13ms/step - loss: 67.3527 - val_loss: 112.2121
# Epoch 70/100
# 23/23 - 0s - 9ms/step - loss: 65.5699 - val_loss: 115.8792
# Epoch 71/100
# 23/23 - 0s - 13ms/step - loss: 63.3204 - val_loss: 105.5685
# Epoch 72/100
# 23/23 - 0s - 14ms/step - loss: 62.3594 - val_loss: 108.3187
# Epoch 73/100
# 23/23 - 0s - 12ms/step - loss: 59.6480 - val_loss: 111.7111
# Epoch 74/100
# 23/23 - 0s - 9ms/step - loss: 57.9486 - val_loss: 106.3344
# Epoch 75/100
# 23/23 - 0s - 7ms/step - loss: 56.4844 - val_loss: 108.6258
# Epoch 76/100
# 23/23 - 0s - 6ms/step - loss: 55.3715 - val_loss: 114.6231
# Epoch 77/100
# 23/23 - 0s - 5ms/step - loss: 53.9061 - val_loss: 101.3183
# Epoch 78/100
# 23/23 - 0s - 6ms/step - loss: 52.7217 - val_loss: 107.2164
# Epoch 79/100
# 23/23 - 0s - 5ms/step - loss: 50.8724 - val_loss: 108.9369
# Epoch 80/100
# 23/23 - 0s - 8ms/step - loss: 49.9860 - val_loss: 108.3198
# Epoch 81/100
# 23/23 - 0s - 7ms/step - loss: 48.6954 - val_loss: 104.6999
# Epoch 82/100
# 23/23 - 0s - 12ms/step - loss: 47.8612 - val_loss: 103.4486
# Epoch 83/100
# 23/23 - 0s - 6ms/step - loss: 47.1048 - val_loss: 106.6258
# Epoch 84/100
# 23/23 - 0s - 5ms/step - loss: 45.7907 - val_loss: 107.2324
# Epoch 85/100
# 23/23 - 0s - 6ms/step - loss: 45.7252 - val_loss: 109.6822
# Epoch 86/100
# 23/23 - 0s - 6ms/step - loss: 44.4294 - val_loss: 109.5545
# Epoch 87/100
# 23/23 - 0s - 6ms/step - loss: 43.8866 - val_loss: 105.8568
# Epoch 88/100
# 23/23 - 0s - 15ms/step - loss: 43.0659 - val_loss: 103.8201
# Epoch 89/100
# 23/23 - 0s - 11ms/step - loss: 42.3630 - val_loss: 110.0639
# Epoch 90/100
# 23/23 - 0s - 6ms/step - loss: 41.8018 - val_loss: 104.2102
# Epoch 91/100
# 23/23 - 0s - 6ms/step - loss: 41.1948 - val_loss: 113.4683
# Epoch 92/100
# 23/23 - 0s - 6ms/step - loss: 40.6457 - val_loss: 109.5639
# Epoch 93/100
# 23/23 - 0s - 6ms/step - loss: 39.9667 - val_loss: 105.7315
# Epoch 94/100
# 23/23 - 0s - 6ms/step - loss: 39.6326 - val_loss: 103.6226
# Epoch 95/100
# 23/23 - 0s - 5ms/step - loss: 39.0904 - val_loss: 110.7514
# Epoch 96/100
# 23/23 - 0s - 6ms/step - loss: 38.8994 - val_loss: 103.7690
# Epoch 97/100
# 23/23 - 0s - 5ms/step - loss: 38.3097 - val_loss: 109.5702
# Epoch 98/100
# 23/23 - 0s - 6ms/step - loss: 37.8519 - val_loss: 109.7484
# Epoch 99/100
# 23/23 - 0s - 5ms/step - loss: 37.8735 - val_loss: 110.3310
# Epoch 100/100
# 23/23 - 0s - 7ms/step - loss: 36.6690 - val_loss: 104.6772

# %% [markdown]
# <strong>You can refer to this [link](https://keras.io/models/sequential/) to learn about other functions that you can use for prediction or evaluation.</strong>

# %% [markdown]
# Feel free to vary the following and note what impact each change has on the model's performance:
#
# 1. Increase or decreate number of neurons in hidden layers
# 2. Add more hidden layers
# 3. Increase number of epochs

# %% [markdown]
# <h3>Practice Exercise 1</h3>

# %% [markdown]
# Now using the same dateset,try to recreate regression model featuring five hidden layers, each with 50 nodes and ReLU activation functions, a single output layer, optimized using the Adam optimizer.

# %%
# Write your code here
# Import libraries
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Load the dataset from URL
csv_path = "https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv"
concrete_data = pd.read_csv(csv_path)

# Prepare predictors and target
predictors = concrete_data.drop(columns=['Strength'])
target = concrete_data['Strength']

# Normalize predictors
predictors_norm = (predictors - predictors.mean()) / predictors.std()

# Define the regression model
def build_model():
    model = Sequential()
    model.add(Dense(50, activation='relu', input_shape=(predictors_norm.shape[1],)))
    for _ in range(4):  # Add 4 more hidden layers
        model.add(Dense(50, activation='relu'))
    model.add(Dense(1))  # Output layer
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# Build and summarize the model
model = build_model()
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_9 (Dense)                 │ (None, 50)             │           450 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,701 (41.80 KB)
#  Trainable params: 10,701 (41.80 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Lab Skill Solution

def regression_model():
    input_colm = predictors_norm.shape[1] # Number of input features
    # create model
    model = Sequential()
    model.add(Input(shape=(input_colm,)))  # Set the number of input features
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))  # Output layer

    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# Practical Excerize  No
#  Train and evaluate the model simultaneously using the fit() method by reserving 10% of the data for validation and training the model for 100 epochs

# %%
# Train the model using 10% of data for validation, for 100 epochs
history = model.fit(
    predictors_norm,
    target,
    validation_split=0.1,
    epochs=100,
    verbose=1
)
# Out:
# Epoch 1/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 1479.5656 - val_loss: 1018.8528
# Epoch 2/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1008.6412 - val_loss: 237.0921
# Epoch 3/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 275.9434 - val_loss: 186.5364
# Epoch 4/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 193.3240 - val_loss: 178.7344
# Epoch 5/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 187.6986 - val_loss: 164.9037
# Epoch 6/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 156.9131 - val_loss: 144.4321
# Epoch 7/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 134.2691 - val_loss: 131.3757
# Epoch 8/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 141.2201 - val_loss: 113.2847
# Epoch 9/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 118.0442 - val_loss: 106.0248
# Epoch 10/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 114.5640 - val_loss: 86.4560
# Epoch 11/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 98.6284 - val_loss: 99.7357
# Epoch 12/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 102.5565 - val_loss: 80.1037
# Epoch 13/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 75.6323 - val_loss: 66.1000
# Epoch 14/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 78.5568 - val_loss: 67.4613
# Epoch 15/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 68.0557 - val_loss: 66.3167
# Epoch 16/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 66.2464 - val_loss: 58.7629
# Epoch 17/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 59.3533 - val_loss: 50.5114
# Epoch 18/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 55.7256 - val_loss: 42.4089
# Epoch 19/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 53.9088 - val_loss: 44.1001
# Epoch 20/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 50.0659 - val_loss: 44.3671
# Epoch 21/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 47.7911 - val_loss: 34.2239
# Epoch 22/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 44.8453 - val_loss: 45.3316
# Epoch 23/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 46.1004 - val_loss: 35.5162
# Epoch 24/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 40.0546 - val_loss: 31.9578
# Epoch 25/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 41.2008 - val_loss: 31.6584
# Epoch 26/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 41.1537 - val_loss: 29.7970
# Epoch 27/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 32.6294 - val_loss: 34.3553
# Epoch 28/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 34.3140 - val_loss: 39.1053
# Epoch 29/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 35.9724 - val_loss: 36.7773
# Epoch 30/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 32.5581 - val_loss: 38.2960
# Epoch 31/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 29.4869 - val_loss: 28.5938
# Epoch 32/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.1088 - val_loss: 28.7667
# Epoch 33/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 28.3170 - val_loss: 36.6539
# Epoch 34/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 26.2134 - val_loss: 34.7077
# Epoch 35/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 26.1051 - val_loss: 31.4341
# Epoch 36/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 25.8851 - val_loss: 23.8842
# Epoch 37/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 24.2679 - val_loss: 23.9660
# Epoch 38/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 23.3938 - val_loss: 29.5957
# Epoch 39/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 20.7229 - val_loss: 38.6632
# Epoch 40/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 24.8166 - val_loss: 29.5186
# Epoch 41/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 22.6637 - val_loss: 29.2391
# Epoch 42/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 21.3230 - val_loss: 35.6505
# Epoch 43/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 22.6641 - val_loss: 23.3932
# Epoch 44/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 20.7377 - val_loss: 27.3073
# Epoch 45/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.0597 - val_loss: 22.5876
# Epoch 46/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 20.6734 - val_loss: 22.9313
# Epoch 47/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.6752 - val_loss: 22.1299
# Epoch 48/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.7052 - val_loss: 30.5114
# Epoch 49/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.5222 - val_loss: 23.9715
# Epoch 50/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16.8331 - val_loss: 23.7277
# Epoch 51/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.1718 - val_loss: 30.2127
# Epoch 52/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.6512 - val_loss: 21.7352
# Epoch 53/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.1118 - val_loss: 33.5500
# Epoch 54/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 18.9293 - val_loss: 19.7656
# Epoch 55/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 17.1065 - val_loss: 23.5028
# Epoch 56/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 16.6456 - val_loss: 27.4228
# Epoch 57/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 15.7741 - val_loss: 22.9657
# Epoch 58/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 17.2336 - val_loss: 26.8492
# Epoch 59/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 15.8191 - val_loss: 45.3088
# Epoch 60/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 17.0418 - val_loss: 19.9506
# Epoch 61/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.1287 - val_loss: 25.9357
# Epoch 62/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.6913 - val_loss: 23.4465
# Epoch 63/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.8878 - val_loss: 29.4670
# Epoch 64/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.9615 - val_loss: 19.2731
# Epoch 65/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.2239 - val_loss: 22.4271
# Epoch 66/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14.0922 - val_loss: 26.2535
# Epoch 67/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14.4150 - val_loss: 21.8156
# Epoch 68/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.3693 - val_loss: 21.0156
# Epoch 69/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14.1311 - val_loss: 19.9579
# Epoch 70/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.3875 - val_loss: 20.8669
# Epoch 71/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.8369 - val_loss: 21.5082
# Epoch 72/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13.1972 - val_loss: 20.6223
# Epoch 73/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13.6693 - val_loss: 18.7980
# Epoch 74/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13.7435 - val_loss: 27.1513
# Epoch 75/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13.4110 - val_loss: 21.4632
# Epoch 76/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.3425 - val_loss: 19.9616
# Epoch 77/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.6728 - val_loss: 23.1199
# Epoch 78/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.5366 - val_loss: 20.7834
# Epoch 79/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13.0091 - val_loss: 22.0434
# Epoch 80/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.0290 - val_loss: 17.8751
# Epoch 81/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.2436 - val_loss: 24.7872
# Epoch 82/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 13.3920 - val_loss: 19.3474
# Epoch 83/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.1977 - val_loss: 17.2396
# Epoch 84/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.7851 - val_loss: 24.7923
# Epoch 85/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.5704 - val_loss: 21.3436
# Epoch 86/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.5432 - val_loss: 18.5882
# Epoch 87/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.9537 - val_loss: 21.8476
# Epoch 88/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13.1095 - val_loss: 23.9265
# Epoch 89/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.6902 - val_loss: 29.7281
# Epoch 90/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14.5250 - val_loss: 17.6465
# Epoch 91/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.9787 - val_loss: 19.5870
# Epoch 92/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.3022 - val_loss: 17.7816
# Epoch 93/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.4706 - val_loss: 22.0476
# Epoch 94/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.3381 - val_loss: 19.2277
# Epoch 95/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.7344 - val_loss: 19.6611
# Epoch 96/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.9469 - val_loss: 24.4169
# Epoch 97/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.4774 - val_loss: 22.0994
# Epoch 98/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.9035 - val_loss: 18.4509
# Epoch 99/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.1605 - val_loss: 16.0056
# Epoch 100/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.4029 - val_loss: 23.9604

# %%
#the solution LAB Skills .

#<!-- Your answer is below:
# build the model
model = regression_model()
model.fit(predictors_norm, target, validation_split=0.1, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 29/29 - 2s - 73ms/step - loss: 1502.8789 - val_loss: 898.4654
# Epoch 2/100
# 29/29 - 0s - 6ms/step - loss: 599.9116 - val_loss: 220.7975
# Epoch 3/100
# 29/29 - 0s - 6ms/step - loss: 242.4984 - val_loss: 191.5308
# Epoch 4/100
# 29/29 - 0s - 6ms/step - loss: 198.7513 - val_loss: 191.0491
# Epoch 5/100
# 29/29 - 0s - 9ms/step - loss: 176.5957 - val_loss: 175.4176
# Epoch 6/100
# 29/29 - 0s - 10ms/step - loss: 158.8880 - val_loss: 167.6591
# Epoch 7/100
# 29/29 - 0s - 10ms/step - loss: 142.4429 - val_loss: 157.2991
# Epoch 8/100
# 29/29 - 0s - 5ms/step - loss: 128.5621 - val_loss: 144.9710
# Epoch 9/100
# 29/29 - 0s - 6ms/step - loss: 110.9335 - val_loss: 145.2751
# Epoch 10/100
# 29/29 - 0s - 10ms/step - loss: 96.0273 - val_loss: 116.3958
# Epoch 11/100
# 29/29 - 0s - 5ms/step - loss: 81.5124 - val_loss: 101.2397
# Epoch 12/100
# 29/29 - 0s - 5ms/step - loss: 71.1372 - val_loss: 88.1100
# Epoch 13/100
# 29/29 - 0s - 5ms/step - loss: 62.4493 - val_loss: 84.3231
# Epoch 14/100
# 29/29 - 0s - 5ms/step - loss: 57.7024 - val_loss: 70.0998
# Epoch 15/100
# 29/29 - 0s - 7ms/step - loss: 52.6072 - val_loss: 68.7792
# Epoch 16/100
# 29/29 - 0s - 5ms/step - loss: 49.7995 - val_loss: 61.2753
# Epoch 17/100
# 29/29 - 0s - 5ms/step - loss: 46.4924 - val_loss: 59.9181
# Epoch 18/100
# 29/29 - 0s - 5ms/step - loss: 44.2609 - val_loss: 50.7593
# Epoch 19/100
# 29/29 - 0s - 5ms/step - loss: 40.4668 - val_loss: 45.4482
# Epoch 20/100
# 29/29 - 0s - 5ms/step - loss: 38.5661 - val_loss: 38.6648
# Epoch 21/100
# 29/29 - 0s - 5ms/step - loss: 36.7673 - val_loss: 40.0283
# Epoch 22/100
# 29/29 - 0s - 5ms/step - loss: 35.4140 - val_loss: 39.8678
# Epoch 23/100
# 29/29 - 0s - 5ms/step - loss: 32.1795 - val_loss: 37.8120
# Epoch 24/100
# 29/29 - 0s - 5ms/step - loss: 30.7233 - val_loss: 30.4663
# Epoch 25/100
# 29/29 - 0s - 5ms/step - loss: 29.8036 - val_loss: 40.8551
# Epoch 26/100
# 29/29 - 0s - 5ms/step - loss: 28.7721 - val_loss: 33.7756
# Epoch 27/100
# 29/29 - 0s - 5ms/step - loss: 27.6273 - val_loss: 28.9503
# Epoch 28/100
# 29/29 - 0s - 5ms/step - loss: 25.8768 - val_loss: 33.0037
# Epoch 29/100
# 29/29 - 0s - 10ms/step - loss: 26.1788 - val_loss: 36.3445
# Epoch 30/100
# 29/29 - 0s - 6ms/step - loss: 24.7120 - val_loss: 32.2283
# Epoch 31/100
# 29/29 - 0s - 9ms/step - loss: 25.2190 - val_loss: 23.9602
# Epoch 32/100
# 29/29 - 0s - 5ms/step - loss: 24.3558 - val_loss: 25.6915
# Epoch 33/100
# 29/29 - 0s - 5ms/step - loss: 22.2765 - val_loss: 28.6926
# Epoch 34/100
# 29/29 - 0s - 10ms/step - loss: 21.5984 - val_loss: 26.1881
# Epoch 35/100
# 29/29 - 0s - 8ms/step - loss: 21.2850 - val_loss: 26.9069
# Epoch 36/100
# 29/29 - 0s - 10ms/step - loss: 20.2286 - val_loss: 26.6897
# Epoch 37/100
# 29/29 - 0s - 8ms/step - loss: 20.4887 - val_loss: 24.1542
# Epoch 38/100
# 29/29 - 0s - 11ms/step - loss: 20.6252 - val_loss: 24.4301
# Epoch 39/100
# 29/29 - 0s - 10ms/step - loss: 20.3147 - val_loss: 30.6139
# Epoch 40/100
# 29/29 - 0s - 11ms/step - loss: 20.8177 - val_loss: 24.3469
# Epoch 41/100
# 29/29 - 0s - 12ms/step - loss: 19.3994 - val_loss: 23.6074
# Epoch 42/100
# 29/29 - 0s - 8ms/step - loss: 19.1833 - val_loss: 28.3205
# Epoch 43/100
# 29/29 - 0s - 5ms/step - loss: 20.2345 - val_loss: 22.4356
# Epoch 44/100
# 29/29 - 0s - 10ms/step - loss: 20.0134 - val_loss: 26.8783
# Epoch 45/100
# 29/29 - 0s - 5ms/step - loss: 18.4173 - val_loss: 24.6432
# Epoch 46/100
# 29/29 - 0s - 7ms/step - loss: 17.5159 - val_loss: 23.0798
# Epoch 47/100
# 29/29 - 0s - 5ms/step - loss: 18.4724 - val_loss: 24.1218
# Epoch 48/100
# 29/29 - 0s - 5ms/step - loss: 17.6357 - val_loss: 22.7779
# Epoch 49/100
# 29/29 - 0s - 10ms/step - loss: 17.2700 - val_loss: 23.8489
# Epoch 50/100
# 29/29 - 0s - 5ms/step - loss: 16.6225 - val_loss: 27.8182
# Epoch 51/100
# 29/29 - 0s - 6ms/step - loss: 16.7874 - val_loss: 21.0725
# Epoch 52/100
# 29/29 - 0s - 5ms/step - loss: 16.9312 - val_loss: 20.8329
# Epoch 53/100
# 29/29 - 0s - 5ms/step - loss: 16.0571 - val_loss: 28.5831
# Epoch 54/100
# 29/29 - 0s - 5ms/step - loss: 16.8586 - val_loss: 21.8961
# Epoch 55/100
# 29/29 - 0s - 10ms/step - loss: 16.5166 - val_loss: 22.3080
# Epoch 56/100
# 29/29 - 0s - 11ms/step - loss: 16.5579 - val_loss: 20.7011
# Epoch 57/100
# 29/29 - 0s - 11ms/step - loss: 16.8115 - val_loss: 24.0679
# Epoch 58/100
# 29/29 - 0s - 9ms/step - loss: 15.1803 - val_loss: 19.5675
# Epoch 59/100
# 29/29 - 0s - 10ms/step - loss: 14.5046 - val_loss: 19.7187
# Epoch 60/100
# 29/29 - 0s - 5ms/step - loss: 15.6763 - val_loss: 27.4496
# Epoch 61/100
# 29/29 - 0s - 5ms/step - loss: 14.6231 - val_loss: 20.0492
# Epoch 62/100
# 29/29 - 0s - 5ms/step - loss: 14.9898 - val_loss: 20.4528
# Epoch 63/100
# 29/29 - 0s - 5ms/step - loss: 14.5254 - val_loss: 19.9944
# Epoch 64/100
# 29/29 - 0s - 5ms/step - loss: 14.2556 - val_loss: 19.5837
# Epoch 65/100
# 29/29 - 0s - 5ms/step - loss: 14.2540 - val_loss: 23.6212
# Epoch 66/100
# 29/29 - 0s - 11ms/step - loss: 14.6496 - val_loss: 18.2810
# Epoch 67/100
# 29/29 - 0s - 10ms/step - loss: 14.3911 - val_loss: 19.4216
# Epoch 68/100
# 29/29 - 0s - 5ms/step - loss: 14.2086 - val_loss: 18.4450
# Epoch 69/100
# 29/29 - 0s - 5ms/step - loss: 14.1946 - val_loss: 17.9200
# Epoch 70/100
# 29/29 - 0s - 5ms/step - loss: 13.3884 - val_loss: 18.2232
# Epoch 71/100
# 29/29 - 0s - 5ms/step - loss: 14.1848 - val_loss: 18.9716
# Epoch 72/100
# 29/29 - 0s - 5ms/step - loss: 13.1458 - val_loss: 17.6341
# Epoch 73/100
# 29/29 - 0s - 5ms/step - loss: 13.3890 - val_loss: 21.3924
# Epoch 74/100
# 29/29 - 0s - 5ms/step - loss: 14.4887 - val_loss: 17.3859
# Epoch 75/100
# 29/29 - 0s - 10ms/step - loss: 13.2391 - val_loss: 19.8503
# Epoch 76/100
# 29/29 - 0s - 5ms/step - loss: 13.0114 - val_loss: 17.8732
# Epoch 77/100
# 29/29 - 0s - 5ms/step - loss: 13.8213 - val_loss: 17.4279
# Epoch 78/100
# 29/29 - 0s - 6ms/step - loss: 13.6135 - val_loss: 17.3284
# Epoch 79/100
# 29/29 - 0s - 5ms/step - loss: 13.1868 - val_loss: 18.6080
# Epoch 80/100
# 29/29 - 0s - 5ms/step - loss: 13.1773 - val_loss: 18.0867
# Epoch 81/100
# 29/29 - 0s - 5ms/step - loss: 14.1408 - val_loss: 21.7255
# Epoch 82/100
# 29/29 - 0s - 5ms/step - loss: 13.6254 - val_loss: 19.4063
# Epoch 83/100
# 29/29 - 0s - 10ms/step - loss: 14.8951 - val_loss: 16.9756
# Epoch 84/100
# 29/29 - 0s - 5ms/step - loss: 12.1612 - val_loss: 16.9095
# Epoch 85/100
# 29/29 - 0s - 5ms/step - loss: 12.2707 - val_loss: 17.5378
# Epoch 86/100
# 29/29 - 0s - 10ms/step - loss: 12.8548 - val_loss: 20.3045
# Epoch 87/100
# 29/29 - 0s - 5ms/step - loss: 12.4558 - val_loss: 16.6821
# Epoch 88/100
# 29/29 - 0s - 5ms/step - loss: 12.4641 - val_loss: 16.1467
# Epoch 89/100
# 29/29 - 0s - 10ms/step - loss: 13.3669 - val_loss: 16.5609
# Epoch 90/100
# 29/29 - 0s - 5ms/step - loss: 12.8605 - val_loss: 16.3314
# Epoch 91/100
# 29/29 - 0s - 5ms/step - loss: 12.3061 - val_loss: 16.7226
# Epoch 92/100
# 29/29 - 0s - 5ms/step - loss: 12.0590 - val_loss: 17.8582
# Epoch 93/100
# 29/29 - 0s - 5ms/step - loss: 13.1574 - val_loss: 16.8324
# Epoch 94/100
# 29/29 - 0s - 6ms/step - loss: 11.9486 - val_loss: 15.6302
# Epoch 95/100
# 29/29 - 0s - 6ms/step - loss: 12.6098 - val_loss: 17.9942
# Epoch 96/100
# 29/29 - 0s - 9ms/step - loss: 12.1250 - val_loss: 16.4122
# Epoch 97/100
# 29/29 - 0s - 8ms/step - loss: 11.7362 - val_loss: 15.3417
# Epoch 98/100
# 29/29 - 0s - 10ms/step - loss: 11.5171 - val_loss: 15.6667
# Epoch 99/100
# 29/29 - 0s - 12ms/step - loss: 12.8238 - val_loss: 16.1869
# Epoch 100/100
# 29/29 - 0s - 10ms/step - loss: 12.3808 - val_loss: 15.9280

# %% [markdown]
#  ### Thank you for completing this lab!
#
# This notebook was created by [Alex Aklson](https://www.linkedin.com/in/aklson/). I hope you found this lab interesting and educational. Feel free to contact me if you have any questions!

# %% [markdown]
# <!--
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2024-11-20  | 3.0  | Aman  |  Updated the library versions to current |
# | 2020-09-21  | 2.0  | Srishti  |  Migrated Lab to Markdown and added to course repo in GitLab |
#
#
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation. All rights reserved. <h3/>

# %% [markdown]
# <hr>
#
# Copyright &copy; [IBM Developer Skills Network](https://cognitiveclass.ai/?utm_source=bducopyrightlink&utm_medium=dswb&utm_campaign=bdu). This notebook and its source code are released under the terms of the [MIT License](https://opensource.org/license/mit).

# %%
# Separate features and target variable
concrete_data_columns = concrete_data.columns
predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']]  # all columns except target
target = concrete_data['Strength']

# Normalize the predictors
predictors_norm = (predictors - predictors.mean()) / predictors.std()

# Confirm shape
predictors_norm.shape, target.shape
